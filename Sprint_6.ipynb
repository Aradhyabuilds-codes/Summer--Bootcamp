# %%
# Machine Learning

# %%
#Feature:
#Label:
#Prediction Problem

# %%
#vectors are a list of numbers , How words are represented as vectors
#Vectors are lists of numbers
#



import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
student_a = np.array([6,85,78])
student_b = np.array ([3,78,55])

print("Student A vector", student_a)
print("Student B vector", student_b)
# Out:
# Student A vector [ 6 85 78]
# Student B vector [ 3 78 55]

# %%
point_a = np.array([6,78])
point_b = np.array([3,55])

distance = np.sqrt((point_a[0] - point_b[0])**2 + (point_a[1] - point_b[1])**2)
print("Distance between point_a and point_b:", distance)
# Out:
# Distance between point_a and point_b: 23.194827009486403

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

students = pd.DataFrame({
    "name": ["Aarav", "Riya", "Kabir", "Meera", "Dev", "Sara"],
    "study_hours": [6, 3, 8, 2, 5, 7],
    "attendance": [85, 70, 90, 60, 78, 92],
    "previous_marks": [78, 55, 88, 35, 65, 84],
    "final_marks": [82, 58, 91, 40, 70, 88]
})


import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='study_hours', y='final_marks', data=students, hue='name', s=100)

for i, row in students.iterrows():
    plt.text(row['study_hours'] + 0.1, row['final_marks'], row['name'], horizontalalignment='left', size='small', color='black')

plt.title('Study Hours vs. Final Marks for Students')
plt.xlabel('Study Hours')
plt.ylabel('Final Marks')
plt.grid(True)
plt.show()

# %%
students = pd.DataFrame({
    "name": ["Aarav", "Riya", "Kabir", "Meera", "Dev", "Sara"],
    "study_hours": [6, 3, 8, 2, 5, 7],
    "attendance": [85, 70, 90, 60, 78, 92],
    "previous_marks": [78, 55, 88, 35, 65, 84],
    "final_marks": [82, 58, 91, 40, 70, 88]
})
#Regression - because here we are just trying to predict the value  the numerical values

# %%
#will the differnce between cat and dog be higher than elephant aqnd bottle? why cat and dog || cat and mouse || dog and garlic

# %%
#basic idea for all recommendation and clustering systems, MAIN CONCEPT: NEAREST NEIGHBOUR

# %%
#AI systems compare data ad points
#tests becomes tokens how -- how tokens becomes vectors -- how RNNS rea sequence -- how LSIMs improve -- what transfromers came after them

# %% [markdown]
# Distance: Asks how far apart the two data points are

# %% [markdown]
# Similarity: How close or related are the two data points

# %% [markdown]
# recmmendation system
# sound recommendation
# google photos
# image clustering (image similarity )
# Pinterest
# RAG system
# Retrieval Augmented Generation
# Google maps
# App Drawer

# %%
students = pd.DataFrame({
    "name": ["Aarav", "Riya", "Kabir", "Meera", "Dev", "Sara"],
    "study_hours": [6, 3, 8, 2, 5, 7],
    "attendance": [85, 70, 90, 60, 78, 92],
    "previous_marks": [78, 55, 88, 35, 65, 84],
    "final_marks": [82, 58, 91, 40, 70, 88]
})

# %%
feature_columns = ["study_hours", "attendance", "previous_marks"]
student_vectors =  students[feature_columns].values
print(student_vectors)
# Out:
# [[ 6 85 78]
#  [ 3 70 55]
#  [ 8 90 88]
#  [ 2 60 35]
#  [ 5 78 65]
#  [ 7 92 84]]

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(student_vectors)

similarity_df = pd.DataFrame(similarity_matrix, index=students["name"], columns=students["name"])

similarity_df
# Out:
# name      Aarav      Riya     Kabir     Meera       Dev      Sara
# name
# Aarav  1.000000  0.996913  0.999434  0.976875  0.998860  0.999988
# Riya   0.996913  1.000000  0.993724  0.990505  0.999467  0.997017
# Kabir  0.999434  0.993724  1.000000  0.969344  0.996756  0.999391
# Meera  0.976875  0.990505  0.969344  1.000000  0.985958  0.977304
# Dev    0.998860  0.999467  0.996756  0.985958  1.000000  0.998956
# Sara   0.999988  0.997017  0.999391  0.977304  0.998956  1.000000

# %%
#2 types of data
#client side data
#reel meta data
#recommendation
#NLP
#vectors - n dimensions

# %%
from matplotlib import MatplotlibDeprecationWarning
#embeddings

#an embedding is a vector that represents MatplotlibDeprecationWarning
#words , images products , users, sentences converted into embeddings
#cat - dog || monkey - banana || dog - banana || cat - bottle
#model do not read english directly

# %%
#RAG systems we coverts documents into embeddings

# %%
#Tokenisation using OpenAI tokeniser
#Tokens
#SOTA model(state of the art model)

# %%
#Tokens can be full words, parts of words , spaces , punctuates and special chunks
#Text -- Token -- token id -- embeddings models

#If the model ignores the order of token then meaning will be lost.
#Text --- Tokens --- Token_id --- Embeddings --- Model

# %%
sentence =  "The movie was not good"

tokens = sentence.lower().split()
print(tokens)
# Out:
# ['the', 'movie', 'was', 'not', 'good']

# %%
vocab = {
    "the": 1,
    "movie": 2,
    "was": 3,
    "not": 4,
    "good": 5
}
token_ids = [vocab[word] for word in tokens]

print(token_ids)
# Out:
# [1, 2, 3, 4, 5]

# %%
from platform import python_revision
Dog bites man
Man bites dog

# The movies was good
# The movies was  not good
the movies was good not


#eg-3
I only said she sole my phone
Only I said she stole my phone
I said only she stole my phone
I said she only stole my phone

# %%
sentences=[
    "dog bites man",
    "man bites dog",
    "the movie was good",
    "the movie was not good"
]

for sentence in sentences:
    print(sentence,"?->", sentence.split())
# Out:
# dog bites man ?-> ['dog', 'bites', 'man']
# man bites dog ?-> ['man', 'bites', 'dog']
# the movie was good ?-> ['the', 'movie', 'was', 'good']
# the movie was not good ?-> ['the', 'movie', 'was', 'not', 'good']

# %%
positive_words = ["good", "great", "excellent", "love", "enjoy"]
negative_words = ["bad", "terrible", "poor", "hate", "boring"]

def simple_sentiment(sentence):
    words = sentence.lower().replace(".", "").split()

    score = 0

    for word in words:
        if word in positive_words:
            score += 1
        elif word in negative_words:
            score -= 1

    if score > 0:
        return "Positive"
    elif score < 0:
        return "Negative"
    else:
        return "Neutral"

print(simple_sentiment("The movie was good"))
print(simple_sentiment("The movie was bad"))
print(simple_sentiment("The movie was not good"))
# Out:
# Positive
# Negative
# Positive

# %%
positive_words = ["good" ,"great" , "amazing" , "excellent" , "love"]
negative_words = ["bad" , "terrible" , "hate" , "poor" , "boring"]
def simple_sentiment(sentence):
  words = sentence.lower().replace(".","").split()
  score = 0
  for word in words:
    if word in positive_words:
      score+=1
    elif word in negative_words:
      score-=1
  if score > 0:
    return "Positive"
  elif score < 0:
    return "Negative"
  else:
    return "Neutral"
print(simple_sentiment("The movie was good"))
print(simple_sentiment("The movie was not good"))
print(simple_sentiment("The movie was bad"))
# Out:
# Positive
# Positive
# Negative

# %%
#RNN
#Recurrent - something repeats
#In RNN the same cell is udes again and again across sequence
#Each word enter the sequence one by one

# %%
#RNN intitution and archtecture

#recurrent > neural > network

#The movie was not good.
#At time step t
#Current Input = x_t (current token)
#Previous Memory = h_(t-1) (updated memory)
#new_memory = h_t
#Output = y_t-- positive intent (positive sentiment )
